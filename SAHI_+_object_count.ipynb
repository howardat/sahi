# %% [markdown]
# <a href="https://colab.research.google.com/github/howardat/sahi/blob/main/SAHI_%2B_object_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ultralytics YOLO11 with SAHI
#
# This notebook serves as the starting point for using the YOLO11 model with [SAHI (Slicing Aided Hyper Inference)](https://docs.ultralytics.com/guides/sahi-tiled-inference/).
#
# ### What is Sliced Inference?
#
# Sliced Inference refers to the practice of subdividing a large or high-resolution image into smaller segments (slices), conducting object detection on these slices, and then recompiling the slices to reconstruct the object locations on the original image. This technique is invaluable in scenarios where computational resources are limited or when working with extremely high-resolution images that could otherwise lead to memory issues.
#
# ### Benefits of Sliced Inference
#
# - **Reduced Computational Burden**: Smaller image slices are faster to process, and they consume less memory, enabling smoother operation on lower-end hardware.
#
# - **Preserved Detection Quality**: Since each slice is treated independently, there is no reduction in the quality of object detection, provided the slices are large enough to capture the objects of interest.
#
# - **Enhanced Scalability**: The technique allows for object detection to be more easily scaled across different sizes and resolutions of images, making it ideal for a wide range of applications from satellite imagery to medical diagnostics.

# %% [markdown]
# ### Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics sahi
import ultralytics
from ultralytics.utils.downloads import safe_download
ultralytics.checks()
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.1/112.6 GB disk)

# %% [markdown]
# ### Clone Repository
#
# - Clone the `ultralytics` repository.
# - `%cd` to the examples section.
# - Move to `YOLOv8-SAHI-Inference-Video` folder.

# %%
# Clone ultralytics repo
# !git clone https://github.com/ultralytics/ultralytics

# cd to local directory
# %cd ultralytics/examples/YOLOv8-SAHI-Inference-Video
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 72864, done.
# remote: Counting objects: 100% (468/468), done.
# remote: Compressing objects: 100% (248/248), done.
# remote: Total 72864 (delta 352), reused 221 (delta 220), pack-reused 72396 (from 3)
# Receiving objects: 100% (72864/72864), 39.16 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (54622/54622), done.
# /content/ultralytics/examples/YOLOv8-SAHI-Inference-Video

# %% [markdown]
# ### Download the Sample Video
#
# - If you want to use your own video, you can skip this step.

# %% [markdown]
# ### Inference using SAHI
#
# The output results will be stored in `ultralytics/ultralytics/examples/YOLOv8-SAHI-Inference-Video/`

# %%
#if you want to change model file
# !python yolov8_sahi.py --source "/content/.png" --weights "/content/best.pt" --save-img
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# Performing prediction on 60 slices.
# object address  : 0x11b1a07c9a80
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %% [markdown]
# ### Inference WITHOUT SAHI

# %%
# !yolo predict source=/content/3243946-uhd_3840_2160_30fps.mp4 model=/content/best.pt show_labels=False line_width=1 show_conf=False
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 42.9ms
# video 1/1 (frame 2/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 76 Persons, 8.3ms
# video 1/1 (frame 3/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 9.0ms
# video 1/1 (frame 4/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 9.0ms
# video 1/1 (frame 5/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.6ms
# video 1/1 (frame 6/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 8.5ms
# video 1/1 (frame 7/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 91 Persons, 8.7ms
# video 1/1 (frame 8/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.6ms
# video 1/1 (frame 9/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 76 Persons, 8.5ms
# video 1/1 (frame 10/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.4ms
# video 1/1 (frame 11/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 12.2ms
# video 1/1 (frame 12/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 8.5ms
# video 1/1 (frame 13/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 68 Persons, 8.5ms
# video 1/1 (frame 14/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 79 Persons, 8.5ms
# video 1/1 (frame 15/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.7ms
# video 1/1 (frame 16/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.3ms
# video 1/1 (frame 17/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.7ms
# video 1/1 (frame 18/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 94 Persons, 11.3ms
# video 1/1 (frame 19/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.6ms
# video 1/1 (frame 20/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 70 Persons, 8.3ms
# video 1/1 (frame 21/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 8.5ms
# video 1/1 (frame 22/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 67 Persons, 8.7ms
# video 1/1 (frame 23/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 8.5ms
# video 1/1 (frame 24/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.3ms
# video 1/1 (frame 25/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 78 Persons, 8.7ms
# video 1/1 (frame 26/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 78 Persons, 8.6ms
# video 1/1 (frame 27/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 8.4ms
# video 1/1 (frame 28/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 9.1ms
# video 1/1 (frame 29/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.8ms
# video 1/1 (frame 30/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 96 Persons, 9.9ms
# video 1/1 (frame 31/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 97 Persons, 7.5ms
# video 1/1 (frame 32/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 99 Persons, 7.6ms
# video 1/1 (frame 33/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 94 Persons, 8.2ms
# video 1/1 (frame 34/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 92 Persons, 13.8ms
# video 1/1 (frame 35/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 7.7ms
# video 1/1 (frame 36/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 101 Persons, 8.1ms
# video 1/1 (frame 37/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 19.9ms
# video 1/1 (frame 38/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 96 Persons, 8.4ms
# video 1/1 (frame 39/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 11.4ms
# video 1/1 (frame 40/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 91 Persons, 17.6ms
# video 1/1 (frame 41/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 101 Persons, 8.7ms
# video 1/1 (frame 42/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 100 Persons, 8.5ms
# video 1/1 (frame 43/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 105 Persons, 8.6ms
# video 1/1 (frame 44/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 103 Persons, 8.4ms
# video 1/1 (frame 45/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 100 Persons, 8.6ms
# video 1/1 (frame 46/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 96 Persons, 10.1ms
# video 1/1 (frame 47/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 99 Persons, 8.7ms
# video 1/1 (frame 48/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 103 Persons, 8.6ms
# video 1/1 (frame 49/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 97 Persons, 8.4ms
# video 1/1 (frame 50/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.3ms
# video 1/1 (frame 51/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 102 Persons, 8.3ms
# video 1/1 (frame 52/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 104 Persons, 8.8ms
# video 1/1 (frame 53/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 103 Persons, 8.7ms
# video 1/1 (frame 54/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.4ms
# video 1/1 (frame 55/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.4ms
# video 1/1 (frame 56/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 8.6ms
# video 1/1 (frame 57/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 83 Persons, 8.7ms
# video 1/1 (frame 58/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 8.4ms
# video 1/1 (frame 59/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.5ms
# video 1/1 (frame 60/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.6ms
# video 1/1 (frame 61/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 9.5ms
# video 1/1 (frame 62/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.5ms
# video 1/1 (frame 63/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 96 Persons, 8.4ms
# video 1/1 (frame 64/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 8.5ms
# video 1/1 (frame 65/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 9.3ms
# video 1/1 (frame 66/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 78 Persons, 8.7ms
# video 1/1 (frame 67/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 10.4ms
# video 1/1 (frame 68/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.5ms
# video 1/1 (frame 69/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.5ms
# video 1/1 (frame 70/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 90 Persons, 8.3ms
# video 1/1 (frame 71/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.4ms
# video 1/1 (frame 72/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.5ms
# video 1/1 (frame 73/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 85 Persons, 8.6ms
# video 1/1 (frame 74/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 78 Persons, 14.7ms
# video 1/1 (frame 75/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.5ms
# video 1/1 (frame 76/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 90 Persons, 9.1ms
# video 1/1 (frame 77/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.6ms
# video 1/1 (frame 78/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 92 Persons, 8.8ms
# video 1/1 (frame 79/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.9ms
# video 1/1 (frame 80/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.5ms
# video 1/1 (frame 81/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 8.5ms
# video 1/1 (frame 82/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.5ms
# video 1/1 (frame 83/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 85 Persons, 8.5ms
# video 1/1 (frame 84/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.7ms
# video 1/1 (frame 85/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 8.7ms
# video 1/1 (frame 86/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 8.8ms
# video 1/1 (frame 87/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 69 Persons, 8.7ms
# video 1/1 (frame 88/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 72 Persons, 7.8ms
# video 1/1 (frame 89/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 76 Persons, 8.2ms
# video 1/1 (frame 90/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 8.5ms
# video 1/1 (frame 91/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 8.6ms
# video 1/1 (frame 92/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.5ms
# video 1/1 (frame 93/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 12.1ms
# video 1/1 (frame 94/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 79 Persons, 8.6ms
# video 1/1 (frame 95/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 65 Persons, 8.6ms
# video 1/1 (frame 96/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 62 Persons, 9.5ms
# video 1/1 (frame 97/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 61 Persons, 8.4ms
# video 1/1 (frame 98/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 69 Persons, 8.5ms
# video 1/1 (frame 99/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 59 Persons, 8.6ms
# video 1/1 (frame 100/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 63 Persons, 8.6ms
# video 1/1 (frame 101/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 53 Persons, 8.6ms
# video 1/1 (frame 102/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 55 Persons, 8.4ms
# video 1/1 (frame 103/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 57 Persons, 8.8ms
# video 1/1 (frame 104/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 63 Persons, 8.7ms
# video 1/1 (frame 105/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 64 Persons, 8.8ms
# video 1/1 (frame 106/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 8.0ms
# video 1/1 (frame 107/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 12.9ms
# video 1/1 (frame 108/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 67 Persons, 8.9ms
# video 1/1 (frame 109/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 15.9ms
# video 1/1 (frame 110/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 37.3ms
# video 1/1 (frame 111/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 15.2ms
# video 1/1 (frame 112/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 9.2ms
# video 1/1 (frame 113/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 61 Persons, 7.7ms
# video 1/1 (frame 114/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 68 Persons, 19.3ms
# video 1/1 (frame 115/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 67 Persons, 10.8ms
# video 1/1 (frame 116/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 64 Persons, 12.8ms
# video 1/1 (frame 117/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 70 Persons, 8.5ms
# video 1/1 (frame 118/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.4ms
# video 1/1 (frame 119/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 8.6ms
# video 1/1 (frame 120/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 97 Persons, 8.8ms
# video 1/1 (frame 121/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 90 Persons, 8.6ms
# video 1/1 (frame 122/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.2ms
# video 1/1 (frame 123/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 92 Persons, 8.8ms
# video 1/1 (frame 124/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.3ms
# video 1/1 (frame 125/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 90 Persons, 8.9ms
# video 1/1 (frame 126/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 76 Persons, 8.7ms
# video 1/1 (frame 127/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 72 Persons, 8.6ms
# video 1/1 (frame 128/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 8.3ms
# video 1/1 (frame 129/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.6ms
# video 1/1 (frame 130/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.6ms
# video 1/1 (frame 131/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 70 Persons, 8.3ms
# video 1/1 (frame 132/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 10.4ms
# video 1/1 (frame 133/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.5ms
# video 1/1 (frame 134/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 8.3ms
# video 1/1 (frame 135/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 67 Persons, 8.6ms
# video 1/1 (frame 136/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 79 Persons, 8.6ms
# video 1/1 (frame 137/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.5ms
# video 1/1 (frame 138/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 68 Persons, 8.5ms
# video 1/1 (frame 139/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 8.7ms
# video 1/1 (frame 140/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 57 Persons, 8.6ms
# video 1/1 (frame 141/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 59 Persons, 8.5ms
# video 1/1 (frame 142/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 60 Persons, 8.4ms
# video 1/1 (frame 143/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 54 Persons, 8.7ms
# video 1/1 (frame 144/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 64 Persons, 8.6ms
# video 1/1 (frame 145/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 66 Persons, 8.4ms
# video 1/1 (frame 146/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 61 Persons, 8.7ms
# video 1/1 (frame 147/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 69 Persons, 8.4ms
# video 1/1 (frame 148/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 63 Persons, 8.7ms
# video 1/1 (frame 149/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 61 Persons, 9.4ms
# video 1/1 (frame 150/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 70 Persons, 12.0ms
# video 1/1 (frame 151/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 70 Persons, 8.6ms
# video 1/1 (frame 152/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 79 Persons, 8.6ms
# video 1/1 (frame 153/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 65 Persons, 8.4ms
# video 1/1 (frame 154/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 59 Persons, 8.6ms
# video 1/1 (frame 155/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 55 Persons, 8.6ms
# video 1/1 (frame 156/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 60 Persons, 8.6ms
# video 1/1 (frame 157/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 64 Persons, 8.8ms
# video 1/1 (frame 158/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 59 Persons, 8.5ms
# video 1/1 (frame 159/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 65 Persons, 8.6ms
# video 1/1 (frame 160/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 59 Persons, 8.5ms
# video 1/1 (frame 161/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 58 Persons, 8.4ms
# video 1/1 (frame 162/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 55 Persons, 8.6ms
# video 1/1 (frame 163/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 51 Persons, 8.6ms
# video 1/1 (frame 164/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 61 Persons, 8.5ms
# video 1/1 (frame 165/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 62 Persons, 8.6ms
# video 1/1 (frame 166/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 69 Persons, 8.6ms
# video 1/1 (frame 167/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.7ms
# video 1/1 (frame 168/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 60 Persons, 8.5ms
# video 1/1 (frame 169/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 69 Persons, 8.4ms
# video 1/1 (frame 170/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 72 Persons, 8.5ms
# video 1/1 (frame 171/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.6ms
# video 1/1 (frame 172/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 78 Persons, 8.5ms
# video 1/1 (frame 173/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 64 Persons, 8.3ms
# video 1/1 (frame 174/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 65 Persons, 8.7ms
# video 1/1 (frame 175/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 8.8ms
# video 1/1 (frame 176/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.6ms
# video 1/1 (frame 177/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 8.8ms
# video 1/1 (frame 178/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 7.8ms
# video 1/1 (frame 179/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 9.4ms
# video 1/1 (frame 180/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 8.5ms
# video 1/1 (frame 181/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 95 Persons, 8.5ms
# video 1/1 (frame 182/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 99 Persons, 19.2ms
# video 1/1 (frame 183/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 18.3ms
# video 1/1 (frame 184/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 15.6ms
# video 1/1 (frame 185/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 92 Persons, 16.2ms
# video 1/1 (frame 186/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 7.7ms
# video 1/1 (frame 187/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 15.6ms
# video 1/1 (frame 188/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 25.4ms
# video 1/1 (frame 189/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 72 Persons, 16.7ms
# video 1/1 (frame 190/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 11.1ms
# video 1/1 (frame 191/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 85 Persons, 9.0ms
# video 1/1 (frame 192/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.6ms
# video 1/1 (frame 193/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 75 Persons, 8.5ms
# video 1/1 (frame 194/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.8ms
# video 1/1 (frame 195/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.8ms
# video 1/1 (frame 196/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 83 Persons, 8.6ms
# video 1/1 (frame 197/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 8.3ms
# video 1/1 (frame 198/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 8.7ms
# video 1/1 (frame 199/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 13.0ms
# video 1/1 (frame 200/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 97 Persons, 8.5ms
# video 1/1 (frame 201/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 8.4ms
# video 1/1 (frame 202/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 91 Persons, 8.5ms
# video 1/1 (frame 203/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 99 Persons, 8.7ms
# video 1/1 (frame 204/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 103 Persons, 8.6ms
# video 1/1 (frame 205/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.4ms
# video 1/1 (frame 206/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 101 Persons, 11.0ms
# video 1/1 (frame 207/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 97 Persons, 8.5ms
# video 1/1 (frame 208/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 100 Persons, 8.9ms
# video 1/1 (frame 209/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 108 Persons, 8.4ms
# video 1/1 (frame 210/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 8.6ms
# video 1/1 (frame 211/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.5ms
# video 1/1 (frame 212/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 84 Persons, 9.1ms
# video 1/1 (frame 213/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 12.9ms
# video 1/1 (frame 214/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.5ms
# video 1/1 (frame 215/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 8.6ms
# video 1/1 (frame 216/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.3ms
# video 1/1 (frame 217/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 89 Persons, 8.5ms
# video 1/1 (frame 218/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 76 Persons, 11.1ms
# video 1/1 (frame 219/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 82 Persons, 8.5ms
# video 1/1 (frame 220/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 77 Persons, 8.3ms
# video 1/1 (frame 221/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.6ms
# video 1/1 (frame 222/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.7ms
# video 1/1 (frame 223/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 92 Persons, 8.6ms
# video 1/1 (frame 224/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 83 Persons, 8.3ms
# video 1/1 (frame 225/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 85 Persons, 8.5ms
# video 1/1 (frame 226/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 17.8ms
# video 1/1 (frame 227/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 71 Persons, 8.5ms
# video 1/1 (frame 228/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 67 Persons, 8.5ms
# video 1/1 (frame 229/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 60 Persons, 8.6ms
# video 1/1 (frame 230/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 65 Persons, 8.7ms
# video 1/1 (frame 231/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.6ms
# video 1/1 (frame 232/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 10.9ms
# video 1/1 (frame 233/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 8.7ms
# video 1/1 (frame 234/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.8ms
# video 1/1 (frame 235/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 10.4ms
# video 1/1 (frame 236/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 8.9ms
# video 1/1 (frame 237/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.6ms
# video 1/1 (frame 238/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 93 Persons, 8.4ms
# video 1/1 (frame 239/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 86 Persons, 8.6ms
# video 1/1 (frame 240/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 83 Persons, 8.5ms
# video 1/1 (frame 241/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.5ms
# video 1/1 (frame 242/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 80 Persons, 8.4ms
# video 1/1 (frame 243/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 83 Persons, 8.6ms
# video 1/1 (frame 244/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 90 Persons, 8.5ms
# video 1/1 (frame 245/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 81 Persons, 8.5ms
# video 1/1 (frame 246/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 74 Persons, 8.5ms
# video 1/1 (frame 247/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 73 Persons, 8.6ms
# video 1/1 (frame 248/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 5.7ms
# video 1/1 (frame 249/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 88 Persons, 6.4ms
# video 1/1 (frame 250/250) /content/3243946-uhd_3840_2160_30fps.mp4: 384x640 87 Persons, 6.1ms
# Speed: 3.6ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/ultralytics/examples/YOLOv8-SAHI-Inference-Video/runs/detect/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
